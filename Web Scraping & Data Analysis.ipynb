# %% [markdown]
# # TASK

# %% [raw]
# To scrape the data from the Wikipedia page 'https://en.wikipedia.org/wiki/List_of_largest_companies_in_India' and conduct data analysis using pandas.

# %% [markdown]
# # WEB SCRAPING

# %%
# Importing BeautifulSoup Library for pulling data out of HTML files.

from bs4 import BeautifulSoup
import requests

# %%
# Specifing the URL of the webpage to be scraped
url = 'https://en.wikipedia.org/wiki/List_of_largest_companies_in_India'

# Using the HTML parser to analyse the HTML content retrieved from the webpage
page = requests.get(url)
soup = BeautifulSoup(page.text, 'html')

# %%
# Accessing the table from the HTML code
table = soup.find_all('table', class_ = 'wikitable sortable')[1]

# %%
# Finding the column headers using the 'th' tag
table_titles = table.find_all('th')
table_titles
# Out:
# [<th>Rank
#  </th>,
#  <th>Name
#  </th>,
#  <th>Industry
#  </th>,
#  <th>Revenue<br/><small>(in  <b>₹ Crore</b>)</small>
#  </th>,
#  <th>Revenue growth
#  </th>,
#  <th>Profits<br/><small>(in  <b>₹ Crore</b>)</small>
#  </th>,
#  <th>Headquarters
#  </th>,
#  <th><a href="/wiki/List_of_public_sector_undertakings_in_India" title="List of public sector undertakings in India">State Controlled</a>
#  </th>]

# %%
# Extracting the text from the list of elements 
table_headers = [title.text.strip() for title in table_titles]
print(table_headers)
# Out:
# ['Rank', 'Name', 'Industry', 'Revenue(in  ₹ Crore)', 'Revenue growth', 'Profits(in  ₹ Crore)', 'Headquarters', 'State Controlled']

# %%
# Importing Pandas and creating a dataframe 
import pandas as pd 
df = pd.DataFrame(columns = table_headers)
df
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Industry, Revenue(in  ₹ Crore), Revenue growth, Profits(in  ₹ Crore), Headquarters, State Controlled]
# Index: []

# %%
# Extracting the text content from each cell of the row and appending the data to the dataframe
column_data = table.find_all('tr')
for row in column_data[1:]:
    row_data = row.find_all('td')
    individual_row_data = [title.text.strip() for title in row_data]
    length = len(df)
    df.loc[length] = individual_row_data
df
# Out:
#    Rank                                    Name            Industry  \
# 0     1                  Indian Oil Corporation         Oil and gas
# 1     2             Reliance Industries Limited         Oil and gas
# 2     3         Oil and Natural Gas Corporation         Oil and gas
# 3     4                     State Bank of India             Banking
# 4     5                             Tata Motors          Automotive
# 5     6                        Bharat Petroleum         Oil and gas
# 6     7                     Hindustan Petroleum         Oil and gas
# 7     8                          Rajesh Exports  Gems and jewellery
# 8     9                              Tata Steel      Iron and steel
# 9    10                              Coal India   Metals and mining
# 10   11               Tata Consultancy Services            Infotech
# 11   12                         Larsen & Toubro       Capital goods
# 12   13                     Hindalco Industries   Metals and mining
# 13   14                              ICICI Bank             Banking
# 14   15                       Vedanta Resources   Metals and mining
# 15   16                               HDFC Bank             Banking
# 16   17                     Mahindra & Mahindra          Automotive
# 17   18                            NTPC Limited           Utilities
# 18   19                           Bharti Airtel   Telecommunication
# 19   20                     Maruti Suzuki India          Automotive
# 20   21                                 Infosys            Infotech
# 21   22                           Nayara Energy         Oil and gas
# 22   23                                    HDFC          Financials
# 23   24                           JSW Steel Ltd      Iron and steel
# 24   25                               Axis Bank             Banking
# 25   26                Steel Authority of India      Iron and steel
# 26   27                    Punjab National Bank             Banking
# 27   28                       Grasim Industries         Diversified
# 28   29                                   Wipro            Infotech
# 29   30                  Motherson Sumi Systems          Automotive
# 30   31                                    GAIL         Oil and gas
# 31   32                          Bank of Baroda             Banking
# 32   33                        HCL Technologies            Infotech
# 33   34                                    MRPL         Oil and gas
# 34   35                             Canara Bank             Banking
# 35   36                             ITC Limited      Consumer goods
# 36   37                           Bank of India             Banking
# 37   38  General Insurance Corporation of India           Insurance
# 38   39                     Kotak Mahindra Bank             Banking
# 39   40                     Union Bank of India             Banking
# 40   41                      Hindustan Unilever      Consumer goods
# 41   42                          Vodafone India   Telecommunication
# 42   43                              Tata Power           Utilities
# 43   44           Chennai Petroleum Corporation         Oil and gas
# 44   45                           Hero MotoCorp          Automotive
# 45   46                           Tech Mahindra            Infotech
# 46   47                        UltraTech Cement              Cement
# 47   48                            Petronet LNG         Oil and gas
# 48   49         Power Grid Corporation of India           Utilities
# 49   50                           Bajaj Finserv          Financials
#
#    Revenue(in  ₹ Crore) Revenue growth Profits(in  ₹ Crore) Headquarters  \
# 0               424,321          13.2%               22,189    New Delhi
# 1               410,295          28.2%               36,075       Mumbai
# 2               333,143          11.0%               22,106    New Delhi
# 3               306,528           2.6%               −4,556       Mumbai
# 4               301,175           7.9%                8,989       Mumbai
# 5               238,638          13.7%                9,009       Mumbai
# 6               221,693          13.4%                7,218       Mumbai
# 7               187,748          22.5%                1,266    Bangalore
# 8               147,192          25.3%               13,434       Mumbai
# 9               132,897           5.3%                7,020      Kolkata
# 10              126,745           3.6%               25,826       Mumbai
# 11              122,743          10.6%                7,370       Mumbai
# 12              120,428          15.5%                6,083       Mumbai
# 13              118,969           4.9%                7,712       Mumbai
# 14              102,192          30.8%               10,342   London, UK
# 15              101,344          17.6%               18,510       Mumbai
# 16               96,377          12.2%                7,510       Mumbai
# 17               90,144           7.7%               10,544    New Delhi
# 18               86,704          13.0%                1,099    New Delhi
# 19               81,978          15.6%                7,880    New Delhi
# 20               73,762           3.1%               16,029    Bangalore
# 21               73,015          10.7%                  576       Mumbai
# 22               72,596          18.9%               16,255       Mumbai
# 23               70,148          22.6%                6,214       Mumbai
# 24               58,477           1.5%                  456       Mumbai
# 25               57,626          28.8%                 −281    New Delhi
# 26               57,608           0.7%              −12,130    New Delhi
# 27               57,273          54.9%                2,679       Mumbai
# 28               56,986           1.6%                8,003    Bangalore
# 29               56,839          32.7%                1,597        Noida
# 30               55,503          11.6%                4,799    New Delhi
# 31               54,048           3.1%               −1,887     Vadodara
# 32               51,695           6.3%                8,721        Noida
# 33               50,209           8.9%                1,993    Mangalore
# 34               48,743           1.2%               −3,951    Bangalore
# 35               44,674           1.6%               11,271      Kolkata
# 36               44,158           4.8%               −5,961       Mumbai
# 37               43,555          38.9%                3,146       Mumbai
# 38               38,813          14.2%                6,201       Mumbai
# 39               38,413           0.4%               −5,212       Mumbai
# 40               36,088           7.1%                5,214       Mumbai
# 41               34,855          18.9%                7,766       Mumbai
# 42               33,213          12.8%                2,477       Mumbai
# 43               33,187          20.0%                  927      Chennai
# 44               33,141          12.9%                3,720    New Delhi
# 45               32,190           7.6%                3,800         Pune
# 46               32,106          23.7%                2,222       Mumbai
# 47               30,949          23.9%                2,110    New Delhi
# 48               30,908          16.1%                8,198      Gurgaon
# 49               30,599          24.9%                2,741         Pune
#
#    State Controlled
# 0               Yes
# 1
# 2               Yes
# 3               Yes
# 4
# 5               Yes
# 6               Yes
# 7
# 8
# 9               Yes
# 10
# 11
# 12
# 13
# 14
# 15
# 16
# 17              Yes
# 18
# 19
# 20
# 21
# 22
# 23
# 24              Yes
# 25              Yes
# 26              Yes
# 27
# 28
# 29
# 30              Yes
# 31              Yes
# 32
# 33              Yes
# 34              Yes
# 35
# 36              Yes
# 37              Yes
# 38
# 39              Yes
# 40
# 41
# 42
# 43              Yes
# 44
# 45
# 46
# 47              Yes
# 48              Yes
# 49

# %% [markdown]
# # DATA CLEANING

# %%
# Renaming the Revenue growth column to Revenue growth %
df.rename(columns={'Revenue growth': 'Revenue growth %'}, inplace=True)
df
# Out:
#    Rank                                    Name            Industry  \
# 0     1                  Indian Oil Corporation         Oil and gas
# 1     2             Reliance Industries Limited         Oil and gas
# 2     3         Oil and Natural Gas Corporation         Oil and gas
# 3     4                     State Bank of India             Banking
# 4     5                             Tata Motors          Automotive
# 5     6                        Bharat Petroleum         Oil and gas
# 6     7                     Hindustan Petroleum         Oil and gas
# 7     8                          Rajesh Exports  Gems and jewellery
# 8     9                              Tata Steel      Iron and steel
# 9    10                              Coal India   Metals and mining
# 10   11               Tata Consultancy Services            Infotech
# 11   12                         Larsen & Toubro       Capital goods
# 12   13                     Hindalco Industries   Metals and mining
# 13   14                              ICICI Bank             Banking
# 14   15                       Vedanta Resources   Metals and mining
# 15   16                               HDFC Bank             Banking
# 16   17                     Mahindra & Mahindra          Automotive
# 17   18                            NTPC Limited           Utilities
# 18   19                           Bharti Airtel   Telecommunication
# 19   20                     Maruti Suzuki India          Automotive
# 20   21                                 Infosys            Infotech
# 21   22                           Nayara Energy         Oil and gas
# 22   23                                    HDFC          Financials
# 23   24                           JSW Steel Ltd      Iron and steel
# 24   25                               Axis Bank             Banking
# 25   26                Steel Authority of India      Iron and steel
# 26   27                    Punjab National Bank             Banking
# 27   28                       Grasim Industries         Diversified
# 28   29                                   Wipro            Infotech
# 29   30                  Motherson Sumi Systems          Automotive
# 30   31                                    GAIL         Oil and gas
# 31   32                          Bank of Baroda             Banking
# 32   33                        HCL Technologies            Infotech
# 33   34                                    MRPL         Oil and gas
# 34   35                             Canara Bank             Banking
# 35   36                             ITC Limited      Consumer goods
# 36   37                           Bank of India             Banking
# 37   38  General Insurance Corporation of India           Insurance
# 38   39                     Kotak Mahindra Bank             Banking
# 39   40                     Union Bank of India             Banking
# 40   41                      Hindustan Unilever      Consumer goods
# 41   42                          Vodafone India   Telecommunication
# 42   43                              Tata Power           Utilities
# 43   44           Chennai Petroleum Corporation         Oil and gas
# 44   45                           Hero MotoCorp          Automotive
# 45   46                           Tech Mahindra            Infotech
# 46   47                        UltraTech Cement              Cement
# 47   48                            Petronet LNG         Oil and gas
# 48   49         Power Grid Corporation of India           Utilities
# 49   50                           Bajaj Finserv          Financials
#
#    Revenue(in  ₹ Crore) Revenue growth % Profits(in  ₹ Crore) Headquarters  \
# 0               424,321            13.2%               22,189    New Delhi
# 1               410,295            28.2%               36,075       Mumbai
# 2               333,143            11.0%               22,106    New Delhi
# 3               306,528             2.6%               −4,556       Mumbai
# 4               301,175             7.9%                8,989       Mumbai
# 5               238,638            13.7%                9,009       Mumbai
# 6               221,693            13.4%                7,218       Mumbai
# 7               187,748            22.5%                1,266    Bangalore
# 8               147,192            25.3%               13,434       Mumbai
# 9               132,897             5.3%                7,020      Kolkata
# 10              126,745             3.6%               25,826       Mumbai
# 11              122,743            10.6%                7,370       Mumbai
# 12              120,428            15.5%                6,083       Mumbai
# 13              118,969             4.9%                7,712       Mumbai
# 14              102,192            30.8%               10,342   London, UK
# 15              101,344            17.6%               18,510       Mumbai
# 16               96,377            12.2%                7,510       Mumbai
# 17               90,144             7.7%               10,544    New Delhi
# 18               86,704            13.0%                1,099    New Delhi
# 19               81,978            15.6%                7,880    New Delhi
# 20               73,762             3.1%               16,029    Bangalore
# 21               73,015            10.7%                  576       Mumbai
# 22               72,596            18.9%               16,255       Mumbai
# 23               70,148            22.6%                6,214       Mumbai
# 24               58,477             1.5%                  456       Mumbai
# 25               57,626            28.8%                 −281    New Delhi
# 26               57,608             0.7%              −12,130    New Delhi
# 27               57,273            54.9%                2,679       Mumbai
# 28               56,986             1.6%                8,003    Bangalore
# 29               56,839            32.7%                1,597        Noida
# 30               55,503            11.6%                4,799    New Delhi
# 31               54,048             3.1%               −1,887     Vadodara
# 32               51,695             6.3%                8,721        Noida
# 33               50,209             8.9%                1,993    Mangalore
# 34               48,743             1.2%               −3,951    Bangalore
# 35               44,674             1.6%               11,271      Kolkata
# 36               44,158             4.8%               −5,961       Mumbai
# 37               43,555            38.9%                3,146       Mumbai
# 38               38,813            14.2%                6,201       Mumbai
# 39               38,413             0.4%               −5,212       Mumbai
# 40               36,088             7.1%                5,214       Mumbai
# 41               34,855            18.9%                7,766       Mumbai
# 42               33,213            12.8%                2,477       Mumbai
# 43               33,187            20.0%                  927      Chennai
# 44               33,141            12.9%                3,720    New Delhi
# 45               32,190             7.6%                3,800         Pune
# 46               32,106            23.7%                2,222       Mumbai
# 47               30,949            23.9%                2,110    New Delhi
# 48               30,908            16.1%                8,198      Gurgaon
# 49               30,599            24.9%                2,741         Pune
#
#    State Controlled
# 0               Yes
# 1
# 2               Yes
# 3               Yes
# 4
# 5               Yes
# 6               Yes
# 7
# 8
# 9               Yes
# 10
# 11
# 12
# 13
# 14
# 15
# 16
# 17              Yes
# 18
# 19
# 20
# 21
# 22
# 23
# 24              Yes
# 25              Yes
# 26              Yes
# 27
# 28
# 29
# 30              Yes
# 31              Yes
# 32
# 33              Yes
# 34              Yes
# 35
# 36              Yes
# 37              Yes
# 38
# 39              Yes
# 40
# 41
# 42
# 43              Yes
# 44
# 45
# 46
# 47              Yes
# 48              Yes
# 49

# %%
#Removing the '%' symbol from the Revenue Growth % column values and then converting them to floating-point numbers
df['Revenue growth %'] = df['Revenue growth %'].str.replace('%', '').astype(float)
df
# Out:
#    Rank                                    Name            Industry  \
# 0     1                  Indian Oil Corporation         Oil and gas
# 1     2             Reliance Industries Limited         Oil and gas
# 2     3         Oil and Natural Gas Corporation         Oil and gas
# 3     4                     State Bank of India             Banking
# 4     5                             Tata Motors          Automotive
# 5     6                        Bharat Petroleum         Oil and gas
# 6     7                     Hindustan Petroleum         Oil and gas
# 7     8                          Rajesh Exports  Gems and jewellery
# 8     9                              Tata Steel      Iron and steel
# 9    10                              Coal India   Metals and mining
# 10   11               Tata Consultancy Services            Infotech
# 11   12                         Larsen & Toubro       Capital goods
# 12   13                     Hindalco Industries   Metals and mining
# 13   14                              ICICI Bank             Banking
# 14   15                       Vedanta Resources   Metals and mining
# 15   16                               HDFC Bank             Banking
# 16   17                     Mahindra & Mahindra          Automotive
# 17   18                            NTPC Limited           Utilities
# 18   19                           Bharti Airtel   Telecommunication
# 19   20                     Maruti Suzuki India          Automotive
# 20   21                                 Infosys            Infotech
# 21   22                           Nayara Energy         Oil and gas
# 22   23                                    HDFC          Financials
# 23   24                           JSW Steel Ltd      Iron and steel
# 24   25                               Axis Bank             Banking
# 25   26                Steel Authority of India      Iron and steel
# 26   27                    Punjab National Bank             Banking
# 27   28                       Grasim Industries         Diversified
# 28   29                                   Wipro            Infotech
# 29   30                  Motherson Sumi Systems          Automotive
# 30   31                                    GAIL         Oil and gas
# 31   32                          Bank of Baroda             Banking
# 32   33                        HCL Technologies            Infotech
# 33   34                                    MRPL         Oil and gas
# 34   35                             Canara Bank             Banking
# 35   36                             ITC Limited      Consumer goods
# 36   37                           Bank of India             Banking
# 37   38  General Insurance Corporation of India           Insurance
# 38   39                     Kotak Mahindra Bank             Banking
# 39   40                     Union Bank of India             Banking
# 40   41                      Hindustan Unilever      Consumer goods
# 41   42                          Vodafone India   Telecommunication
# 42   43                              Tata Power           Utilities
# 43   44           Chennai Petroleum Corporation         Oil and gas
# 44   45                           Hero MotoCorp          Automotive
# 45   46                           Tech Mahindra            Infotech
# 46   47                        UltraTech Cement              Cement
# 47   48                            Petronet LNG         Oil and gas
# 48   49         Power Grid Corporation of India           Utilities
# 49   50                           Bajaj Finserv          Financials
#
#    Revenue(in  ₹ Crore)  Revenue growth % Profits(in  ₹ Crore) Headquarters  \
# 0               424,321              13.2               22,189    New Delhi
# 1               410,295              28.2               36,075       Mumbai
# 2               333,143              11.0               22,106    New Delhi
# 3               306,528               2.6               −4,556       Mumbai
# 4               301,175               7.9                8,989       Mumbai
# 5               238,638              13.7                9,009       Mumbai
# 6               221,693              13.4                7,218       Mumbai
# 7               187,748              22.5                1,266    Bangalore
# 8               147,192              25.3               13,434       Mumbai
# 9               132,897               5.3                7,020      Kolkata
# 10              126,745               3.6               25,826       Mumbai
# 11              122,743              10.6                7,370       Mumbai
# 12              120,428              15.5                6,083       Mumbai
# 13              118,969               4.9                7,712       Mumbai
# 14              102,192              30.8               10,342   London, UK
# 15              101,344              17.6               18,510       Mumbai
# 16               96,377              12.2                7,510       Mumbai
# 17               90,144               7.7               10,544    New Delhi
# 18               86,704              13.0                1,099    New Delhi
# 19               81,978              15.6                7,880    New Delhi
# 20               73,762               3.1               16,029    Bangalore
# 21               73,015              10.7                  576       Mumbai
# 22               72,596              18.9               16,255       Mumbai
# 23               70,148              22.6                6,214       Mumbai
# 24               58,477               1.5                  456       Mumbai
# 25               57,626              28.8                 −281    New Delhi
# 26               57,608               0.7              −12,130    New Delhi
# 27               57,273              54.9                2,679       Mumbai
# 28               56,986               1.6                8,003    Bangalore
# 29               56,839              32.7                1,597        Noida
# 30               55,503              11.6                4,799    New Delhi
# 31               54,048               3.1               −1,887     Vadodara
# 32               51,695               6.3                8,721        Noida
# 33               50,209               8.9                1,993    Mangalore
# 34               48,743               1.2               −3,951    Bangalore
# 35               44,674               1.6               11,271      Kolkata
# 36               44,158               4.8               −5,961       Mumbai
# 37               43,555              38.9                3,146       Mumbai
# 38               38,813              14.2                6,201       Mumbai
# 39               38,413               0.4               −5,212       Mumbai
# 40               36,088               7.1                5,214       Mumbai
# 41               34,855              18.9                7,766       Mumbai
# 42               33,213              12.8                2,477       Mumbai
# 43               33,187              20.0                  927      Chennai
# 44               33,141              12.9                3,720    New Delhi
# 45               32,190               7.6                3,800         Pune
# 46               32,106              23.7                2,222       Mumbai
# 47               30,949              23.9                2,110    New Delhi
# 48               30,908              16.1                8,198      Gurgaon
# 49               30,599              24.9                2,741         Pune
#
#    State Controlled
# 0               Yes
# 1
# 2               Yes
# 3               Yes
# 4
# 5               Yes
# 6               Yes
# 7
# 8
# 9               Yes
# 10
# 11
# 12
# 13
# 14
# 15
# 16
# 17              Yes
# 18
# 19
# 20
# 21
# 22
# 23
# 24              Yes
# 25              Yes
# 26              Yes
# 27
# 28
# 29
# 30              Yes
# 31              Yes
# 32
# 33              Yes
# 34              Yes
# 35
# 36              Yes
# 37              Yes
# 38
# 39              Yes
# 40
# 41
# 42
# 43              Yes
# 44
# 45
# 46
# 47              Yes
# 48              Yes
# 49

# %%
# Replacing the white spaces in the column State Controlled with appropriate text
df['State Controlled'] = df['State Controlled'].replace(r'^\s*$', 'No', regex=True)
df
# Out:
#    Rank                                    Name            Industry  \
# 0     1                  Indian Oil Corporation         Oil and gas
# 1     2             Reliance Industries Limited         Oil and gas
# 2     3         Oil and Natural Gas Corporation         Oil and gas
# 3     4                     State Bank of India             Banking
# 4     5                             Tata Motors          Automotive
# 5     6                        Bharat Petroleum         Oil and gas
# 6     7                     Hindustan Petroleum         Oil and gas
# 7     8                          Rajesh Exports  Gems and jewellery
# 8     9                              Tata Steel      Iron and steel
# 9    10                              Coal India   Metals and mining
# 10   11               Tata Consultancy Services            Infotech
# 11   12                         Larsen & Toubro       Capital goods
# 12   13                     Hindalco Industries   Metals and mining
# 13   14                              ICICI Bank             Banking
# 14   15                       Vedanta Resources   Metals and mining
# 15   16                               HDFC Bank             Banking
# 16   17                     Mahindra & Mahindra          Automotive
# 17   18                            NTPC Limited           Utilities
# 18   19                           Bharti Airtel   Telecommunication
# 19   20                     Maruti Suzuki India          Automotive
# 20   21                                 Infosys            Infotech
# 21   22                           Nayara Energy         Oil and gas
# 22   23                                    HDFC          Financials
# 23   24                           JSW Steel Ltd      Iron and steel
# 24   25                               Axis Bank             Banking
# 25   26                Steel Authority of India      Iron and steel
# 26   27                    Punjab National Bank             Banking
# 27   28                       Grasim Industries         Diversified
# 28   29                                   Wipro            Infotech
# 29   30                  Motherson Sumi Systems          Automotive
# 30   31                                    GAIL         Oil and gas
# 31   32                          Bank of Baroda             Banking
# 32   33                        HCL Technologies            Infotech
# 33   34                                    MRPL         Oil and gas
# 34   35                             Canara Bank             Banking
# 35   36                             ITC Limited      Consumer goods
# 36   37                           Bank of India             Banking
# 37   38  General Insurance Corporation of India           Insurance
# 38   39                     Kotak Mahindra Bank             Banking
# 39   40                     Union Bank of India             Banking
# 40   41                      Hindustan Unilever      Consumer goods
# 41   42                          Vodafone India   Telecommunication
# 42   43                              Tata Power           Utilities
# 43   44           Chennai Petroleum Corporation         Oil and gas
# 44   45                           Hero MotoCorp          Automotive
# 45   46                           Tech Mahindra            Infotech
# 46   47                        UltraTech Cement              Cement
# 47   48                            Petronet LNG         Oil and gas
# 48   49         Power Grid Corporation of India           Utilities
# 49   50                           Bajaj Finserv          Financials
#
#    Revenue(in  ₹ Crore)  Revenue growth % Profits(in  ₹ Crore) Headquarters  \
# 0               424,321              13.2               22,189    New Delhi
# 1               410,295              28.2               36,075       Mumbai
# 2               333,143              11.0               22,106    New Delhi
# 3               306,528               2.6               −4,556       Mumbai
# 4               301,175               7.9                8,989       Mumbai
# 5               238,638              13.7                9,009       Mumbai
# 6               221,693              13.4                7,218       Mumbai
# 7               187,748              22.5                1,266    Bangalore
# 8               147,192              25.3               13,434       Mumbai
# 9               132,897               5.3                7,020      Kolkata
# 10              126,745               3.6               25,826       Mumbai
# 11              122,743              10.6                7,370       Mumbai
# 12              120,428              15.5                6,083       Mumbai
# 13              118,969               4.9                7,712       Mumbai
# 14              102,192              30.8               10,342   London, UK
# 15              101,344              17.6               18,510       Mumbai
# 16               96,377              12.2                7,510       Mumbai
# 17               90,144               7.7               10,544    New Delhi
# 18               86,704              13.0                1,099    New Delhi
# 19               81,978              15.6                7,880    New Delhi
# 20               73,762               3.1               16,029    Bangalore
# 21               73,015              10.7                  576       Mumbai
# 22               72,596              18.9               16,255       Mumbai
# 23               70,148              22.6                6,214       Mumbai
# 24               58,477               1.5                  456       Mumbai
# 25               57,626              28.8                 −281    New Delhi
# 26               57,608               0.7              −12,130    New Delhi
# 27               57,273              54.9                2,679       Mumbai
# 28               56,986               1.6                8,003    Bangalore
# 29               56,839              32.7                1,597        Noida
# 30               55,503              11.6                4,799    New Delhi
# 31               54,048               3.1               −1,887     Vadodara
# 32               51,695               6.3                8,721        Noida
# 33               50,209               8.9                1,993    Mangalore
# 34               48,743               1.2               −3,951    Bangalore
# 35               44,674               1.6               11,271      Kolkata
# 36               44,158               4.8               −5,961       Mumbai
# 37               43,555              38.9                3,146       Mumbai
# 38               38,813              14.2                6,201       Mumbai
# 39               38,413               0.4               −5,212       Mumbai
# 40               36,088               7.1                5,214       Mumbai
# 41               34,855              18.9                7,766       Mumbai
# 42               33,213              12.8                2,477       Mumbai
# 43               33,187              20.0                  927      Chennai
# 44               33,141              12.9                3,720    New Delhi
# 45               32,190               7.6                3,800         Pune
# 46               32,106              23.7                2,222       Mumbai
# 47               30,949              23.9                2,110    New Delhi
# 48               30,908              16.1                8,198      Gurgaon
# 49               30,599              24.9                2,741         Pune
#
#    State Controlled
# 0               Yes
# 1                No
# 2               Yes
# 3               Yes
# 4                No
# 5               Yes
# 6               Yes
# 7                No
# 8                No
# 9               Yes
# 10               No
# 11               No
# 12               No
# 13               No
# 14               No
# 15               No
# 16               No
# 17              Yes
# 18               No
# 19               No
# 20               No
# 21               No
# 22               No
# 23               No
# 24              Yes
# 25              Yes
# 26              Yes
# 27               No
# 28               No
# 29               No
# 30              Yes
# 31              Yes
# 32               No
# 33              Yes
# 34              Yes
# 35               No
# 36              Yes
# 37              Yes
# 38               No
# 39              Yes
# 40               No
# 41               No
# 42               No
# 43              Yes
# 44               No
# 45               No
# 46               No
# 47              Yes
# 48              Yes
# 49               No

# %%
# Removing comma from the strings and then converting them to floating-point numbers
df['Revenue(in  ₹ Crore)'] = df['Revenue(in  ₹ Crore)'].astype(str).str.replace(',', '').astype(float)

# %%
# Replacing non-standard minus signs ('−') with standard hyphens ('-') in the 'Profits (in ₹ Crore)' column
df['Profits(in  ₹ Crore)'] = df['Profits(in  ₹ Crore)'].str.replace('−', '-')

# Removing comma from the strings and then converting them to floating-point numbers
df['Profits(in  ₹ Crore)'] = df['Profits(in  ₹ Crore)'].astype(str).str.replace(',', '').astype(float)

# %%
# Final Dataframe 
df
# Out:
#    Rank                                    Name            Industry  \
# 0     1                  Indian Oil Corporation         Oil and gas
# 1     2             Reliance Industries Limited         Oil and gas
# 2     3         Oil and Natural Gas Corporation         Oil and gas
# 3     4                     State Bank of India             Banking
# 4     5                             Tata Motors          Automotive
# 5     6                        Bharat Petroleum         Oil and gas
# 6     7                     Hindustan Petroleum         Oil and gas
# 7     8                          Rajesh Exports  Gems and jewellery
# 8     9                              Tata Steel      Iron and steel
# 9    10                              Coal India   Metals and mining
# 10   11               Tata Consultancy Services            Infotech
# 11   12                         Larsen & Toubro       Capital goods
# 12   13                     Hindalco Industries   Metals and mining
# 13   14                              ICICI Bank             Banking
# 14   15                       Vedanta Resources   Metals and mining
# 15   16                               HDFC Bank             Banking
# 16   17                     Mahindra & Mahindra          Automotive
# 17   18                            NTPC Limited           Utilities
# 18   19                           Bharti Airtel   Telecommunication
# 19   20                     Maruti Suzuki India          Automotive
# 20   21                                 Infosys            Infotech
# 21   22                           Nayara Energy         Oil and gas
# 22   23                                    HDFC          Financials
# 23   24                           JSW Steel Ltd      Iron and steel
# 24   25                               Axis Bank             Banking
# 25   26                Steel Authority of India      Iron and steel
# 26   27                    Punjab National Bank             Banking
# 27   28                       Grasim Industries         Diversified
# 28   29                                   Wipro            Infotech
# 29   30                  Motherson Sumi Systems          Automotive
# 30   31                                    GAIL         Oil and gas
# 31   32                          Bank of Baroda             Banking
# 32   33                        HCL Technologies            Infotech
# 33   34                                    MRPL         Oil and gas
# 34   35                             Canara Bank             Banking
# 35   36                             ITC Limited      Consumer goods
# 36   37                           Bank of India             Banking
# 37   38  General Insurance Corporation of India           Insurance
# 38   39                     Kotak Mahindra Bank             Banking
# 39   40                     Union Bank of India             Banking
# 40   41                      Hindustan Unilever      Consumer goods
# 41   42                          Vodafone India   Telecommunication
# 42   43                              Tata Power           Utilities
# 43   44           Chennai Petroleum Corporation         Oil and gas
# 44   45                           Hero MotoCorp          Automotive
# 45   46                           Tech Mahindra            Infotech
# 46   47                        UltraTech Cement              Cement
# 47   48                            Petronet LNG         Oil and gas
# 48   49         Power Grid Corporation of India           Utilities
# 49   50                           Bajaj Finserv          Financials
#
#     Revenue(in  ₹ Crore)  Revenue growth %  Profits(in  ₹ Crore) Headquarters  \
# 0               424321.0              13.2               22189.0    New Delhi
# 1               410295.0              28.2               36075.0       Mumbai
# 2               333143.0              11.0               22106.0    New Delhi
# 3               306528.0               2.6               -4556.0       Mumbai
# 4               301175.0               7.9                8989.0       Mumbai
# 5               238638.0              13.7                9009.0       Mumbai
# 6               221693.0              13.4                7218.0       Mumbai
# 7               187748.0              22.5                1266.0    Bangalore
# 8               147192.0              25.3               13434.0       Mumbai
# 9               132897.0               5.3                7020.0      Kolkata
# 10              126745.0               3.6               25826.0       Mumbai
# 11              122743.0              10.6                7370.0       Mumbai
# 12              120428.0              15.5                6083.0       Mumbai
# 13              118969.0               4.9                7712.0       Mumbai
# 14              102192.0              30.8               10342.0   London, UK
# 15              101344.0              17.6               18510.0       Mumbai
# 16               96377.0              12.2                7510.0       Mumbai
# 17               90144.0               7.7               10544.0    New Delhi
# 18               86704.0              13.0                1099.0    New Delhi
# 19               81978.0              15.6                7880.0    New Delhi
# 20               73762.0               3.1               16029.0    Bangalore
# 21               73015.0              10.7                 576.0       Mumbai
# 22               72596.0              18.9               16255.0       Mumbai
# 23               70148.0              22.6                6214.0       Mumbai
# 24               58477.0               1.5                 456.0       Mumbai
# 25               57626.0              28.8                -281.0    New Delhi
# 26               57608.0               0.7              -12130.0    New Delhi
# 27               57273.0              54.9                2679.0       Mumbai
# 28               56986.0               1.6                8003.0    Bangalore
# 29               56839.0              32.7                1597.0        Noida
# 30               55503.0              11.6                4799.0    New Delhi
# 31               54048.0               3.1               -1887.0     Vadodara
# 32               51695.0               6.3                8721.0        Noida
# 33               50209.0               8.9                1993.0    Mangalore
# 34               48743.0               1.2               -3951.0    Bangalore
# 35               44674.0               1.6               11271.0      Kolkata
# 36               44158.0               4.8               -5961.0       Mumbai
# 37               43555.0              38.9                3146.0       Mumbai
# 38               38813.0              14.2                6201.0       Mumbai
# 39               38413.0               0.4               -5212.0       Mumbai
# 40               36088.0               7.1                5214.0       Mumbai
# 41               34855.0              18.9                7766.0       Mumbai
# 42               33213.0              12.8                2477.0       Mumbai
# 43               33187.0              20.0                 927.0      Chennai
# 44               33141.0              12.9                3720.0    New Delhi
# 45               32190.0               7.6                3800.0         Pune
# 46               32106.0              23.7                2222.0       Mumbai
# 47               30949.0              23.9                2110.0    New Delhi
# 48               30908.0              16.1                8198.0      Gurgaon
# 49               30599.0              24.9                2741.0         Pune
#
#    State Controlled
# 0               Yes
# 1                No
# 2               Yes
# 3               Yes
# 4                No
# 5               Yes
# 6               Yes
# 7                No
# 8                No
# 9               Yes
# 10               No
# 11               No
# 12               No
# 13               No
# 14               No
# 15               No
# 16               No
# 17              Yes
# 18               No
# 19               No
# 20               No
# 21               No
# 22               No
# 23               No
# 24              Yes
# 25              Yes
# 26              Yes
# 27               No
# 28               No
# 29               No
# 30              Yes
# 31              Yes
# 32               No
# 33              Yes
# 34              Yes
# 35               No
# 36              Yes
# 37              Yes
# 38               No
# 39              Yes
# 40               No
# 41               No
# 42               No
# 43              Yes
# 44               No
# 45               No
# 46               No
# 47              Yes
# 48              Yes
# 49               No

# %% [markdown]
# # DATA ANALYSIS

# %%
# QUERY 1 : List out the companies from the Oil and Gas sector

oil_gas_companies = df[df['Industry'] == 'Oil and gas']
columns = ['Name', 'Revenue growth %', 'Profits(in  ₹ Crore)', 'Headquarters', 'State Controlled']
print(oil_gas_companies[columns].to_string(index=False, col_space=23))
# Out:
#                            Name        Revenue growth %    Profits(in  ₹ Crore)            Headquarters        State Controlled
#          Indian Oil Corporation                    13.2                 22189.0               New Delhi                     Yes
#     Reliance Industries Limited                    28.2                 36075.0                  Mumbai                      No
# Oil and Natural Gas Corporation                    11.0                 22106.0               New Delhi                     Yes
#                Bharat Petroleum                    13.7                  9009.0                  Mumbai                     Yes
#             Hindustan Petroleum                    13.4                  7218.0                  Mumbai                     Yes
#                   Nayara Energy                    10.7                   576.0                  Mumbai                      No
#                            GAIL                    11.6                  4799.0               New Delhi                     Yes
#                            MRPL                     8.9                  1993.0               Mangalore                     Yes
#   Chennai Petroleum Corporation                    20.0                   927.0                 Chennai                     Yes
#                    Petronet LNG                    23.9                  2110.0               New Delhi                     Yes

# %%
# QUERY 2 : List out the companies with the highest revenue growth, highest revenue and highest profit

max_revenue_growth = df['Revenue growth %'].max()
company_max_revenue_growth = df.loc[df['Revenue growth %'].idxmax()]['Name']
print("Highest Revenue Growth: ",company_max_revenue_growth,"-",max_revenue_growth,"%")
print("\n")

max_revenue = df['Revenue(in  ₹ Crore)'].max()
company_max_revenue = df.loc[df['Revenue(in  ₹ Crore)'].idxmax()]['Name']
print("Highest Revenue: ",company_max_revenue,"-",max_revenue,"Crores")
print("\n")

max_profits = df['Profits(in  ₹ Crore)'].max()
company_max_profits = df.loc[df['Profits(in  ₹ Crore)'].idxmax()]['Name']
print("Highest Profit: ",company_max_profits,"-",max_profits,"Crores")
# Out:
# Highest Revenue Growth:  Grasim Industries - 54.9 %
#
#
# Highest Revenue:  Indian Oil Corporation - 424321.0 Crores
#
#
# Highest Profit:  Reliance Industries Limited - 36075.0 Crores

# %%
#QUERY 3 : List out the companies that are not state controlled and located in mumbai

scm_companies = df[(df['State Controlled'] == 'No') & (df['Headquarters'] == 'Mumbai')].copy()
scm_companies['Profit %'] = (scm_companies['Profits(in  ₹ Crore)'] / scm_companies['Revenue(in  ₹ Crore)']) * 100
scm_companies['Profit %'] = scm_companies['Profit %'].round(2)
columns = ['Name', 'Revenue(in  ₹ Crore)', 'Revenue growth %', 'Profit %']
print(scm_companies[columns].to_string(index=False, col_space=23))
# Out:
#                        Name    Revenue(in  ₹ Crore)        Revenue growth %                Profit %
# Reliance Industries Limited                410295.0                    28.2                    8.79
#                 Tata Motors                301175.0                     7.9                    2.98
#                  Tata Steel                147192.0                    25.3                    9.13
#   Tata Consultancy Services                126745.0                     3.6                   20.38
#             Larsen & Toubro                122743.0                    10.6                    6.00
#         Hindalco Industries                120428.0                    15.5                    5.05
#                  ICICI Bank                118969.0                     4.9                    6.48
#                   HDFC Bank                101344.0                    17.6                   18.26
#         Mahindra & Mahindra                 96377.0                    12.2                    7.79
#               Nayara Energy                 73015.0                    10.7                    0.79
#                        HDFC                 72596.0                    18.9                   22.39
#               JSW Steel Ltd                 70148.0                    22.6                    8.86
#           Grasim Industries                 57273.0                    54.9                    4.68
#         Kotak Mahindra Bank                 38813.0                    14.2                   15.98
#          Hindustan Unilever                 36088.0                     7.1                   14.45
#              Vodafone India                 34855.0                    18.9                   22.28
#                  Tata Power                 33213.0                    12.8                    7.46
#            UltraTech Cement                 32106.0                    23.7                    6.92

# %%
#QUERY 4 : Plot a bar chart depicting the number of companies in each industry

import matplotlib.pyplot as plt

industry_count = df.groupby('Industry').size()

industry_count.plot(kind ='bar')
plt.xlabel('Industry')
plt.ylabel('Number of Companies')
plt.title('Number of Companies in Each Industry')
plt.show()

# %%
#QUERY 5 : Plot a line chart depicting the average revenue growth of each industry

average_growth = df.groupby('Industry')['Revenue growth %'].mean()

plt.figure(figsize=(15, 5))
average_growth.plot(kind='line', marker='o', color='r')
plt.title('Average Revenue Growth % by Industry')
plt.xlabel('Industry')
plt.ylabel('Average Revenue Growth %')
plt.xticks(range(len(average_growth.index)), average_growth.index, rotation=60)
plt.grid(True)
plt.show()
